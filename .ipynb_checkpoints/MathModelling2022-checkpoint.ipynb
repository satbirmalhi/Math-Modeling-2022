# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import mpld3
mpld3.enable_notebook()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
register_matplotlib_converters()
from time import time
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from scipy.optimize import linprog
def parser(s):
    return datetime.strptime(s, '%Y-%m-%d')
dfB = pd.read_csv('Data/BCHAIN-MKPRU.csv', parse_dates=[0], index_col=0, squeeze=True)
def Prediction(df):
    prediction = pd.DataFrame()
    for i in range(0,len(df)-3):
        train_data = df[0:i+3]
        model = ARMA(train_data, order=(1,0,1))
        model_fit = model.fit(disp=0)
        predictions = model_fit.predict(i+3)
        predictions= pd.DataFrame(predictions)
        prediction = prediction.append(predictions)
    prediction = pd.DataFrame(prediction)
    return prediction
predictionB = Prediction(dfB)
predictionB.columns = ['Value']
predictionB = predictionB.rename_axis(index='Date')
dfB = pd.DataFrame(dfB)
predictionB = dfB[0:3].append(predictionB)
predictionB.columns = ['predicted_value']
dfB = pd.merge(dfB, predictionB, left_index=True, right_index=True)
dfB["PCT"] = 100*( dfB["predicted_value"].shift(periods=-1)- dfB["Value"])/dfB["Value"]
dfB["PCT"] = dfB["PCT"].shift(periods=1)
dfB[["Value","predicted_value"]].plot()
plt.legend(loc=4)
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()
dfG = pd.read_csv('Data/LBMA-GOLD.csv', parse_dates=[0], index_col=0, squeeze=True)
dfG = dfG.fillna(method='ffill')
dfG = dfG.asfreq(pd.infer_freq(dfG.index))
dfG = dfG.fillna(method='ffill')
dfG1 = dfG["2016-09-12":"2019-01-01"]
dfG2 = dfG["2018-12-31":"2021-09-10"]
predictionG1 = Prediction(dfG1)
predictionG2 = Prediction(dfG2)
predictionG1.columns = ['USD (PM)']
predictionG2.columns = ['USD (PM)']
predictionG = predictionG1.append(predictionG2)
dfG = pd.DataFrame(dfG)
predictionG = dfG[0:3].append(predictionG)
predictionG.columns = ['predicted_value']
dfG = pd.merge(dfG, predictionG, left_index=True, right_index=True)
dfG["PCT"] = 100*( dfG["predicted_value"].shift(periods=-1)- dfG["USD (PM)"])/dfG["USD (PM)"]
dfG["PCT"] = dfG["PCT"].shift(periods=1)
ind = 3
x=500/(dfG["USD (PM)"][ind])
y=500/(dfB["Value"][ind])
alpha =0.01
beta = 0.02
portfolio = pd.DataFrame()
for ind in range(0, 1820):
    A = np.array([[dfG['predicted_value'][ind+1]+alpha, dfB['predicted_value'][ind+1]+beta], 
              [dfG['predicted_value'][ind+1], 0], 
             [dfB['predicted_value'][ind+1], 0]])
    b = np.array([dfG["USD (PM)"][ind]*x + dfB["Value"][ind]*y, (dfG["USD (PM)"][ind])*x, (dfB["Value"][ind])*y])
    c = np.array([alpha-dfG['predicted_value'][ind+1], beta-dfB['predicted_value'][ind+1] ])
    res = linprog(c, A_ub = A, b_ub = b)
    x = res.x[0]
    y = res.x[1]
    z = round(res.fun, ndigits=2)
    portfolios= pd.DataFrame({"Portfolio":[dfG["USD (PM)"][ind+1]*x + dfB["Value"][ind+1]*y],
                              "PortfolioG":[dfG["USD (PM)"][ind+1]*x],"PortfolioB":[dfB["Value"][ind+1]*y]})
    portfolio = portfolio.append(portfolios)
portfolio1 = portfolio.reset_index()
portfolio2 =portfolio1.drop(['index'], axis=1)
portfolio = portfolio2
portfolio[["PortfolioG"]].plot()
plt.legend(loc=4)
plt.xlabel("Date")
plt.ylabel("Price")
plt.savefig('Goldat35.png')
portfolio[["Portfolio"]].plot()
plt.legend(loc=4)
plt.xlabel("Date")
plt.ylabel("Price")
plt.savefig('Portfolio.png')
print(portfolio)
print(dfG)
print(dfB)
# Out:
# /usr/local/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
# Out:
#           Portfolio  PortfolioG     PortfolioB
# 0       1015.780175  505.263966     510.516209
# 1       1015.759642  505.263971     510.495671
# 2       1006.033526  500.434933     505.598593
# 3        999.291297  496.539333     502.751964
# 4        995.499072  495.442074     500.056998
# ...             ...         ...            ...
# 1815  280215.011157    0.000000  280215.011157
# 1816  290533.455425    0.000000  290533.455425
# 1817  293470.008656    0.000000  293470.008656
# 1818  297834.913623    0.000000  297834.913623
# 1819  297468.515316    0.000000  297468.515316
#
# [1820 rows x 3 columns]
